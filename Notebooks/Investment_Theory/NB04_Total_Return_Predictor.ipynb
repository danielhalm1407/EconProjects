# %% [markdown]
# # A basic model to try and predict the Total Return of Eligible Stocks:
# ### Predicts the P/E multiple and hence the forecast price -> total return of a group of stocks

# %% [markdown]
# ## Set-Up

# %% [markdown]
# ### Import Packages

# %%
import os
import numpy as np
import pandas as pd
from scipy.optimize import root
import matplotlib.pyplot as plt

# %% [markdown]
# ### Set Starting Parameters

# %%
R = 0.055
b = 1/(1+R)
maturity_g = 0.073
time_frame = 10
start_earnings = 10
__file__ = "NB04_Total_Return_Predictor.ipynb"
current_dir = os.path.dirname(os.path.abspath(__file__))

# %% [markdown]
# ## Import the Bloomberg data from Excel

# %% [markdown]
# ### Read In The Data

# %%
asset_df = pd.read_excel(os.path.join(current_dir, "../../data/Bloomberg_Rankings.xlsx"), sheet_name = "Mid Cap and Above")

# %% [markdown]
# ### Inspect the Data

# %%
asset_df.head(8)
# Out:
#                   ID                           Name    Last Price  \
# 0      IHC UH Equity  International Holding Co PJSC    410.000000
# 1    QNBFB TI Equity              QNB Finansbank AS    328.750000
# 2  ADANIGR IN Equity         Adani Green Energy Ltd   2038.000000
# 3    ADANI IN Equity                Adani Power Ltd    874.500000
# 4      ADE IN Equity          Adani Enterprises Ltd   3645.250000
# 5     SMCI US Equity       Super Micro Computer Inc    762.490723
# 6     BYAN IJ Equity         Bayan Resources Tbk PT  18000.000000
# 7     6920 JP Equity                  Lasertec Corp  40100.000000
#
#    6Y Total Return%  6Y Annualised Return         EPS       FCFPS  \
# 0        300.470588              1.589450   13.526731    4.789175
# 1         72.222393              1.045380   10.867053         NaN
# 2         63.698413              1.003621    6.944302  -74.834324
# 3         46.398374              0.902365   54.003407   45.250976
# 4         43.643866              0.883477   28.427895 -131.325263
# 5         30.004074              0.772433   19.230000  -33.824639
# 6         22.218526              0.689037    0.034590    0.017968
# 7         21.450892              0.679599  742.560000  321.568675
#
#       FCF Yield  EPS Growth  5 YR EPS Growth  5 YR Forecast EPS Growth  \
# 0  1.168091e-02   88.549203       336.721739                336.721739
# 1           NaN   69.538759        92.741867                 92.741867
# 2 -3.671949e-02   12.776022              NaN                       NaN
# 3  5.174497e-02   94.187008              NaN                       NaN
# 4 -3.602641e-02   30.473393        52.594889                 52.594889
# 5 -4.436072e-02   72.776280        80.841010                 80.841010
# 6  9.982250e-07  -46.202778        63.130366                 63.130366
# 7  8.019169e-03  105.626938        71.924868                 71.924868
#
#      Multiple  Earnings Yield  EPS 5 Years Forecast  \
# 0   43.264225        0.023114          21489.034753
# 1   30.251914        0.033056            289.062723
# 2  231.698702        0.004316                   NaN
# 3   16.277971        0.061433                   NaN
# 4  137.441817        0.007276            235.203967
# 5   42.665360        0.023438            371.932307
# 6   32.120832        0.031132              0.399599
# 7   54.047060        0.018502          11153.856393
#
#    5Y Forecast Earnings Yield  1Y Expected TR (No Change in Multiple)  \
# 0                   52.412280                                3.468160
# 1                    0.879278                                0.991131
# 2                         NaN                                     NaN
# 3                         NaN                                     NaN
# 4                    0.064523                                0.537051
# 5                    0.487786                                0.850796
# 6                    0.000022                                0.682090
# 7                    0.278151                                0.751059
#
#    5Y Expected Annualised TR (No Change in Multiple)
# 0                                           4.891563
# 1                                           1.212056
# 2                                                NaN
# 3                                                NaN
# 4                                           0.662944
# 5                                           1.045355
# 6                                           0.810109
# 7                                           0.923087

# %% [markdown]
# ### Drop the rows where "5Y Forecast EPS Growth" is Null
# - We need this for our prediction of the P/E multiple, and then the EPS with which we multiply that multiple by to get the future price.
# - The current rudimentary form of predicting the multiple assumes that investors presume that EPS growth continues at the current rate for a certain set of years and then trails back down to a maturity growth rate. Investors purchase up until the point at which the multiple that they have priced in yields them the minimum expected rate of return, `R`, that they will take.
# - I.e., the multiple today depends on the price and hence multiple tomorrow and so on so forth in a geometric series.
# - Investors could calculate this `R` in any way, whether it be the CAPM or the Fama-French Three-Factor or another model to identify the best hurdle rate/ cost of equity capital they shoud take

# %%
asset_df = asset_df.dropna(subset=['5 YR Forecast EPS Growth'])
# Inspect the column (These figures will be in percentage, not proportion scale)
asset_df["5 YR Forecast EPS Growth"]
# Out:
# 0       336.721739
# 1        92.741867
# 4        52.594889
# 5        80.841010
# 6        63.130366
#            ...
# 1033     12.294384
# 1039    -10.572361
# 1042      8.237525
# 1045     57.864844
# 1047     25.676972
# Name: 5 YR Forecast EPS Growth, Length: 709, dtype: float64

# %%
def predict_multiple(growth, t): 
    growth = min([growth/100,0.30])
    maturity_g = 0.065 + 0.1*(growth - 0.065)
    k_vec_m = 1 + maturity_g
    maturity_multiple = (k_vec_m*b*(1-(k_vec_m*b)**18)/(1-b*k_vec_m))
    maturity_multiple   
    b_vec = [b] * t
    k_vec = [1 + growth] * t
    b_vec = np.cumprod(b_vec)[:t]
    k_vec = np.cumprod(k_vec)[:t]
   
    return sum(k_vec*b_vec) + maturity_multiple*b_vec[-1]*k_vec[-1]


predict_multiple(341.92,5)
# Out:
# np.float64(79.49405534513394)

# %%
asset_df["5Y Multiple"] = asset_df["5 YR Forecast EPS Growth"].apply(lambda x: predict_multiple(x, 5))

# %%
def predict_roi(growth, multiple, fut_multiple): 
    growth = min([growth/100,0.30])
    return (((1+growth)**6)*(1+(1/multiple)+(fut_multiple/multiple)))**1/6

# %% [markdown]
# ## Predict the ROI Corresponding to this

# %%
asset_df["5Y Expected Annualised TR (Change in Multiple)"] = [predict_roi(asset_df["5 YR Forecast EPS Growth"][i], asset_df["Multiple"][i], asset_df["5Y Multiple"][i]) for i in asset_df.index]

# %%
asset_df.head()
# Out:
#                 ID                           Name    Last Price  \
# 0    IHC UH Equity  International Holding Co PJSC    410.000000
# 1  QNBFB TI Equity              QNB Finansbank AS    328.750000
# 4    ADE IN Equity          Adani Enterprises Ltd   3645.250000
# 5   SMCI US Equity       Super Micro Computer Inc    762.490723
# 6   BYAN IJ Equity         Bayan Resources Tbk PT  18000.000000
#
#    6Y Total Return%  6Y Annualised Return        EPS       FCFPS  \
# 0        300.470588              1.589450  13.526731    4.789175
# 1         72.222393              1.045380  10.867053         NaN
# 4         43.643866              0.883477  28.427895 -131.325263
# 5         30.004074              0.772433  19.230000  -33.824639
# 6         22.218526              0.689037   0.034590    0.017968
#
#       FCF Yield  EPS Growth  5 YR EPS Growth  5 YR Forecast EPS Growth  \
# 0  1.168091e-02   88.549203       336.721739                336.721739
# 1           NaN   69.538759        92.741867                 92.741867
# 4 -3.602641e-02   30.473393        52.594889                 52.594889
# 5 -4.436072e-02   72.776280        80.841010                 80.841010
# 6  9.982250e-07  -46.202778        63.130366                 63.130366
#
#      Multiple  Earnings Yield  EPS 5 Years Forecast  \
# 0   43.264225        0.023114          21489.034753
# 1   30.251914        0.033056            289.062723
# 4  137.441817        0.007276            235.203967
# 5   42.665360        0.023438            371.932307
# 6   32.120832        0.031132              0.399599
#
#    5Y Forecast Earnings Yield  1Y Expected TR (No Change in Multiple)  \
# 0                   52.412280                                3.468160
# 1                    0.879278                                0.991131
# 4                    0.064523                                0.537051
# 5                    0.487786                                0.850796
# 6                    0.000022                                0.682090
#
#    5Y Expected Annualised TR (No Change in Multiple)  5Y Multiple  \
# 0                                           4.891563    79.494055
# 1                                           1.212056    79.494055
# 4                                           0.662944    79.494055
# 5                                           1.045355    79.494055
# 6                                           0.810109    79.494055
#
#    5Y Expected Annualised TR (Change in Multiple)
# 0                                        2.301199
# 1                                        2.944991
# 4                                        1.275612
# 5                                        2.322208
# 6                                        2.820447

# %%
asset_df.to_excel(os.path.join(current_dir,"../../data/Top_Stocks.xlsx"))

# %% [markdown]
# ## Re-do with more complicated bloomberg data

# %% [markdown]
# ### Import the data

# %%
df = pd.read_excel(os.path.join(current_dir, "../../data/bloomberg_data.xlsx"))

# %% [markdown]
# ### Rename Some of the columns

# %%
df.rename(columns = {'Unnamed: 0': 'security_key'}, inplace = True)

# %% [markdown]
# ### Take a deeper look at some of the columns, especially annualised performance over the last 5 years

# %%
pd.set_option('display.max_columns', None)
df.sort_values(by = "current_ann_trr_5yr", ascending = False)
# Out:
#        security_key                  security_name  px_last  current_trr_ytd  \
# 182   IHC UH Equity  International Holding Co PJSC  414.500         3.754693
# 240  NVDA US Equity                    NVIDIA Corp  125.830       154.121900
# 309  TSLA US Equity                      Tesla Inc  251.520         1.223442
# 203   LLY US Equity                 Eli Lilly & Co  914.570        57.423540
# 199  KLAC US Equity                       KLA Corp  855.210        47.740160
# ..              ...                            ...      ...              ...
# 245  P911 GR Equity         Dr Ing hc F Porsche AG   71.320        -7.935353
# 255  PLTR US Equity      Palantir Technologies Inc   27.230        58.590560
# 258   PRX NA Equity                      Prosus NV   32.835        21.678700
# 272  ROSN RM Equity            Rosneft Oil Co PJSC  556.150              NaN
# 280  SBER RM Equity        Sberbank of Russia PJSC  313.500              NaN
#
#       cur_mkt_cap  current_trr_ytd_1  current_ann_trr_3yr  \
# 182  9.092223e+11           3.754693            48.553680
# 240  3.095418e+12         154.121900            84.915230
# 309  8.021466e+11           1.223442             4.942127
# 203  8.692123e+11          57.423540            58.498100
# 199  1.151454e+11          47.740160            42.903900
# ..            ...                ...                  ...
# 245  6.497252e+10          -7.935353                  NaN
# 255  6.063839e+10          58.590560             5.661175
# 258  8.467185e+10          21.678700            -2.140393
# 272  5.894177e+12                NaN                  NaN
# 280  6.767508e+12                NaN                  NaN
#
#      current_ann_trr_5yr  month_end_trr_10yr  minimum_total_return  \
# 182            209.09870           79.483020                   NaN
# 240            100.09750           75.716730                   NaN
# 309             74.82077           28.611223                   NaN
# 203             54.49960           33.149180                   NaN
# 199             50.77105           33.369447                   NaN
# ..                   ...                 ...                   ...
# 245                  NaN                 NaN                   NaN
# 255                  NaN                 NaN                   NaN
# 258                  NaN                 NaN                   NaN
# 272                  NaN           14.568560                   NaN
# 280                  NaN           19.087700                   NaN
#
#      hist_trr_prev_1yr  current_trr_mtd  eps_growth  \
# 182          -2.560967         1.593137   84.368610
# 240         239.019100         1.853651  584.659091
# 309         101.721000        27.107340   17.661692
# 203          60.905030         1.015044  -16.017316
# 199          56.029640         3.723425   10.013593
# ..                 ...              ...         ...
# 245         -14.915430         2.589187    4.044118
# 255         167.445400         7.500986         NaN
# 258          -8.503771        -1.277809   62.145326
# 272          79.459110              NaN         NaN
# 280         114.086700              NaN  246.924885
#
#      geo_grow_diluted_eps_cont_ops  diluted_eps_cont_ops_5yr_avg_gr  \
# 182                     196.464049                       280.792101
# 240                      51.441971                       168.466403
# 309                            NaN                              NaN
# 203                      13.459286                        22.494442
# 199                      25.827603                        25.775781
# ..                             ...                              ...
# 245                            NaN                              NaN
# 255                            NaN                              NaN
# 258                      10.844301                        75.982422
# 272                            NaN                              NaN
# 280                      12.248339                              NaN
#
#      5y_geo_growth_diluted_eps   earn_yld    pe_ratio  \
# 182                 215.717287   3.263385   30.643028
# 240                  48.401189   1.364966   73.261887
# 309                        NaN   0.883704  113.160080
# 203                  13.129725   1.133808   88.198379
# 199                  36.480119   2.637979   37.907804
# ..                         ...        ...         ...
# 245                        NaN   7.182267   13.923180
# 255                        NaN   0.461469  216.699291
# 258                  20.394921   7.447539   13.427254
# 272                        NaN        NaN         NaN
# 280                  12.596420  22.606001    4.423604
#
#      five_yr_avg_price_earnings  long_term_price_earnings_ratio  \
# 182                   34.160428                             NaN
# 240                   61.097322                      366.074157
# 309                         NaN                      405.377228
# 203                   38.449955                      135.566601
# 199                   17.870855                       62.973129
# ..                          ...                             ...
# 245                         NaN                             NaN
# 255                         NaN                             NaN
# 258                   18.448145                             NaN
# 272                         NaN                        8.225822
# 280                    6.049010                        6.381916
#
#      best_pe_ratio  pr_eps_growth_plus_yld
# 182            NaN                     NaN
# 240      43.136784               42.817484
# 309      94.449869                     NaN
# 203      62.526150               40.544444
# 199      31.722616                9.645935
# ..             ...                     ...
# 245      12.298672                6.568923
# 255      79.619883                     NaN
# 258      11.597772               46.123187
# 272            NaN                     NaN
# 280            NaN                     NaN
#
# [344 rows x 22 columns]

# %% [markdown]
# ### Define a function to apply some exclusion criteria
# * Get rid of any stocks that were in the bottom 30% of performers in the 1yr, 3yr and 5yr annualised TR
# * Get rid of any stocks with EPS growth in the last year, geometrically over 5 years or average over 5 years in the bottom 20 % of performers

# %%
def exclude(df, first_thresh = 30, second_thresh = 20):
    trr_cols = df.filter(regex='trr')
    for col in trr_cols:
        percentile = np.nanpercentile(df[col], 30)

        # Create a mask to filter rows where each 'trr' column is either NaN or >= the 50th percentile
        mask = (df[col].isna()) | (df[col] >= percentile)

        # Apply the mask to filter the DataFrame for each 'trr' column
        df = df[mask]
    eps_growth_cols = df.filter(regex='(gr.*eps|eps.*gr|gr.*earnings|earnings.*gr)')
    for col in eps_growth_cols:
        percentile = np.nanpercentile(df[col], 30)

        # Create a mask to filter rows where each 'trr' column is either NaN or >= the 50th percentile
        mask = (df[col].isna()) | (df[col] >= percentile)

        # Apply the mask to filter the DataFrame for each 'trr' column
        df = df[mask]
    

    return df

exclude(df)
# Out:
#         security_key                   security_name   px_last  \
# 40    7974 JP Equity                 Nintendo Co Ltd   8897.00
# 77    ANET US Equity             Arista Networks Inc    366.14
# 105   BREN IJ Equity  Barito Renewables Energy Tbk P  10300.00
# 166  GOOGL US Equity                    Alphabet Inc    190.60
# 226   MSFT US Equity                  Microsoft Corp    467.56
# 240   NVDA US Equity                     NVIDIA Corp    125.83
# 323    VGT US Equity  Vanguard Information Technolog    595.91
# 340    XLK US Equity   Technology Select Sector SPDR    232.88
#
#      current_trr_ytd   cur_mkt_cap  current_trr_ytd_1  current_ann_trr_3yr  \
# 40          22.81723  1.155444e+13           22.81723             15.75242
# 77          55.46687  1.147348e+11           55.46687             58.09722
# 105         37.83897  1.377998e+15           37.83897                  NaN
# 166         36.60091  2.363663e+12           36.60091             15.11437
# 226         24.78638  3.475049e+12           24.78638             20.00619
# 240        154.12190  3.095418e+12          154.12190             84.91523
# 323         23.57851  7.719874e+10           23.57851             14.78231
# 340         21.40606  7.253185e+10           21.40606             16.81078
#
#      current_ann_trr_5yr  month_end_trr_10yr  minimum_total_return  \
# 40              20.77975           24.459750                   NaN
# 77              40.39544           36.427448                   NaN
# 105                  NaN                 NaN                   NaN
# 166             27.82583           20.044368                   NaN
# 226             29.02111           28.622857                   NaN
# 240            100.09750           75.716730                   NaN
# 323             23.75562           20.879360              -6.75760
# 340             25.20144           20.971694              -6.27495
#
#      hist_trr_prev_1yr  current_trr_mtd  eps_growth  \
# 40            38.01933         3.985507   13.456827
# 77            94.07499         4.468159   53.061224
# 105                NaN         2.233251         NaN
# 166           58.32480         4.639040   27.233115
# 226           58.19189         4.611251    0.206186
# 240          239.01910         1.853651  584.659091
# 323           52.65349         3.350725         NaN
# 340           56.01636         2.939491         NaN
#
#      geo_grow_diluted_eps_cont_ops  diluted_eps_cont_ops_5yr_avg_gr  \
# 40                       20.622616                        33.361729
# 77                       26.925057                        36.606925
# 105                            NaN                              NaN
# 166                      22.896718                        33.493262
# 226                      21.778598                        21.248099
# 240                      51.441971                       168.466403
# 323                            NaN                              NaN
# 340                            NaN                              NaN
#
#      5y_geo_growth_diluted_eps  earn_yld   pe_ratio  \
# 40                   21.136470  4.736203  21.113959
# 77                   45.328895  1.957851  51.076409
# 105                        NaN       NaN        NaN
# 166                  21.561293  3.468208  28.833333
# 226                  35.474430  2.471377  40.463273
# 240                  48.401189  1.364966  73.261887
# 323                        NaN       NaN        NaN
# 340                        NaN       NaN        NaN
#
#      five_yr_avg_price_earnings  long_term_price_earnings_ratio  \
# 40                    16.599310                       37.757079
# 77                    37.389258                      134.736412
# 105                         NaN                             NaN
# 166                   26.285673                       55.777962
# 226                   32.120102                       69.569266
# 240                   61.097322                      366.074157
# 323                         NaN                             NaN
# 340                         NaN                             NaN
#
#      best_pe_ratio  pr_eps_growth_plus_yld
# 40       30.504802                     NaN
# 77       45.807582                     NaN
# 105            NaN                     NaN
# 166      23.656448               15.114932
# 226      36.754972               15.431684
# 240      43.136784               42.817484
# 323            NaN                     NaN
# 340            NaN                     NaN
