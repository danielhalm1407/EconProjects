# %% [markdown]
# # A basic model to try and predict the Total Return of Eligible Stocks:
# ### Predicts the P/E multiple and hence the forecast price -> total return of a group of stocks

# %% [markdown]
# ## Set-Up

# %% [markdown]
# ### Import Packages

# %%
import os
import sys
import numpy as np
import pandas as pd
from scipy.optimize import root
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import also the custom packages we made for this repository

# %%
__file__ = "NB04_Total_Return_Predictor.ipynb"
current_dir = os.path.dirname(os.path.abspath(__file__))
parent_dir = os.path.abspath(os.path.join(current_dir, '..', '../src'))
data_dir = os.path.abspath(os.path.join(current_dir, '..', '../data'))
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)
from econ_utils import inv_theory as inv
from econ_utils import sql_queries as sqlq

# %% [markdown]
# ### Set Starting Parameters

# %%
R = 0.055
b = 1/(1+R)
maturity_g = 0.073
time_frame = 12
start_earnings = 10

# %% [markdown]
# ## Import the Bloomberg Rankings from Excel

# %% [markdown]
# ### Read In The Data

# %%
asset_df = pd.read_excel(os.path.join(current_dir, "../../data/Bloomberg_Rankings.xlsx"), sheet_name = "Mid Cap and Above")

# %% [markdown]
# ### Inspect the Data

# %%
asset_df.head(8)
# Out:
#                   ID                           Name    Last Price  \
# 0      IHC UH Equity  International Holding Co PJSC    410.000000
# 1    QNBFB TI Equity              QNB Finansbank AS    328.750000
# 2  ADANIGR IN Equity         Adani Green Energy Ltd   2038.000000
# 3    ADANI IN Equity                Adani Power Ltd    874.500000
# 4      ADE IN Equity          Adani Enterprises Ltd   3645.250000
# 5     SMCI US Equity       Super Micro Computer Inc    762.490723
# 6     BYAN IJ Equity         Bayan Resources Tbk PT  18000.000000
# 7     6920 JP Equity                  Lasertec Corp  40100.000000
#
#    6Y Total Return%  6Y Annualised Return         EPS       FCFPS  \
# 0        300.470588              1.589450   13.526731    4.789175
# 1         72.222393              1.045380   10.867053         NaN
# 2         63.698413              1.003621    6.944302  -74.834324
# 3         46.398374              0.902365   54.003407   45.250976
# 4         43.643866              0.883477   28.427895 -131.325263
# 5         30.004074              0.772433   19.230000  -33.824639
# 6         22.218526              0.689037    0.034590    0.017968
# 7         21.450892              0.679599  742.560000  321.568675
#
#       FCF Yield  EPS Growth  5 YR EPS Growth  5 YR Forecast EPS Growth  \
# 0  1.168091e-02   88.549203       336.721739                336.721739
# 1           NaN   69.538759        92.741867                 92.741867
# 2 -3.671949e-02   12.776022              NaN                       NaN
# 3  5.174497e-02   94.187008              NaN                       NaN
# 4 -3.602641e-02   30.473393        52.594889                 52.594889
# 5 -4.436072e-02   72.776280        80.841010                 80.841010
# 6  9.982250e-07  -46.202778        63.130366                 63.130366
# 7  8.019169e-03  105.626938        71.924868                 71.924868
#
#      Multiple  Earnings Yield  EPS 5 Years Forecast  \
# 0   43.264225        0.023114          21489.034753
# 1   30.251914        0.033056            289.062723
# 2  231.698702        0.004316                   NaN
# 3   16.277971        0.061433                   NaN
# 4  137.441817        0.007276            235.203967
# 5   42.665360        0.023438            371.932307
# 6   32.120832        0.031132              0.399599
# 7   54.047060        0.018502          11153.856393
#
#    5Y Forecast Earnings Yield  1Y Expected TR (No Change in Multiple)  \
# 0                   52.412280                                3.468160
# 1                    0.879278                                0.991131
# 2                         NaN                                     NaN
# 3                         NaN                                     NaN
# 4                    0.064523                                0.537051
# 5                    0.487786                                0.850796
# 6                    0.000022                                0.682090
# 7                    0.278151                                0.751059
#
#    5Y Expected Annualised TR (No Change in Multiple)
# 0                                           4.891563
# 1                                           1.212056
# 2                                                NaN
# 3                                                NaN
# 4                                           0.662944
# 5                                           1.045355
# 6                                           0.810109
# 7                                           0.923087

# %% [markdown]
# ### Drop the rows where "5Y Forecast EPS Growth" is Null
# - We need this for our prediction of the P/E multiple, and then the EPS with which we multiply that multiple by to get the future price.
# - The current rudimentary form of predicting the multiple assumes that investors presume that EPS growth continues at the current rate for a certain set of years and then trails back down to a maturity growth rate. Investors purchase up until the point at which the multiple that they have priced in yields them the minimum expected rate of return, `R`, that they will take.
# - I.e., the multiple today depends on the price and hence multiple tomorrow and so on so forth in a geometric series.
# - Investors could calculate this `R` in any way, whether it be the CAPM or the Fama-French Three-Factor or another model to identify the best hurdle rate/ cost of equity capital they shoud take

# %%
asset_df = asset_df.dropna(subset=['5 YR Forecast EPS Growth'])
# Inspect the column (These figures will be in percentage, not proportion scale)
asset_df["5 YR Forecast EPS Growth"]
# Out:
# 0       336.721739
# 1        92.741867
# 4        52.594889
# 5        80.841010
# 6        63.130366
#            ...
# 1033     12.294384
# 1039    -10.572361
# 1042      8.237525
# 1045     57.864844
# 1047     25.676972
# Name: 5 YR Forecast EPS Growth, Length: 709, dtype: float64

# %%
def predict_multiple(growth, t, detail = False, max = 50): 
    growth = growth/100
    maturity_g = 0.065 + 0.1*(growth - 0.065)
    k_vec_m = 1 + maturity_g
    maturity_multiple = (k_vec_m*b*(1-(k_vec_m*b)**time_frame)/(1-b*k_vec_m))
    maturity_multiple   
    b_vec = [b] * t
    k_vec = [1 + growth] * t
    b_vec = np.cumprod(b_vec)[:t]
    k_vec = np.cumprod(k_vec)[:t]
    if detail:
        print(f'Maturity growth rate is assumed to be: {maturity_g}')
        print(f'As a result of the pdv of eps this results in, the maturity multiple is assumed to be: {maturity_multiple}')
        print(f'Pricing in an expected return of {R*100}%, we expect an end of period p/e of...')   
    return float(np.min([sum(k_vec*b_vec) + maturity_multiple*b_vec[-1]*k_vec[-1], max]))


predict_multiple(14,5, detail = True)
# Out:
# Maturity growth rate is assumed to be: 0.07250000000000001
# As a result of the pdv of eps this results in, the maturity multiple is assumed to be: 13.375895034674066
# Pricing in an expected return of 5.5%, we expect an end of period p/e of...
# 26.051838189309326

# %%
asset_df["5Y Multiple"] = asset_df["5 YR Forecast EPS Growth"].apply(lambda x: predict_multiple(x, 5))

# %%
def predict_roi(growth, multiple, fut_multiple, n = 3, payout_rate = 1, detail = False): 
    growth = min([growth/100,0.30])
    fut_price_to_curr_price = ((1+growth)**n)*(fut_multiple/multiple)
    growth_vec = [1+ growth] * n
    cum_growth_vec = np.cumprod(growth_vec)
    cum_income_to_curr_price = (1/multiple)*(np.sum(cum_growth_vec))
    pr = fut_price_to_curr_price
    ir = float(cum_income_to_curr_price)
    tr = pr + ir
    tr_ann = float(tr**(1/n) - 1)
    if detail:
        print(f'Estimated geometric average annual eps growth in the period: {growth*100}%')
        print(f'Cumulative eps growth in the period: {(cum_growth_vec[-1]-1)*100}%')
        print(f'And the P/E is expected to change to: {fut_multiple} from its current {multiple}')
        print(f'Price reaches {(pr)*100}% of the starting price')
        print(f'Cumulative income is {ir*100}% of the starting price')
        print(f'Total Return is {tr*100}%')
        print(f'Annualised to a {n} year period is {tr_ann*100}%')
    return tr_ann 
predict_roi(10, 6, predict_multiple(10,5), detail = True)
# Out:
# Estimated geometric average annual eps growth in the period: 10.0%
# Cumulative eps growth in the period: 33.10000000000004%
# And the P/E is expected to change to: 21.753977144561347 from its current 6
# Price reaches 482.5757263235193% of the starting price
# Cumulative income is 60.683333333333344% of the starting price
# Total Return is 543.2590596568526%
# Annualised to a 3 year period is 75.79330285037489%
# 0.7579330285037489

# %% [markdown]
# ## Predict the ROI Corresponding to this

# %%
asset_df["5Y Expected Annualised TR (Change in Multiple)"] = [predict_roi(asset_df["5 YR Forecast EPS Growth"][i], asset_df["Multiple"][i], asset_df["5Y Multiple"][i]) for i in asset_df.index]

# %%
asset_df.head()
# Out:
#                 ID                           Name    Last Price  \
# 0    IHC UH Equity  International Holding Co PJSC    410.000000
# 1  QNBFB TI Equity              QNB Finansbank AS    328.750000
# 4    ADE IN Equity          Adani Enterprises Ltd   3645.250000
# 5   SMCI US Equity       Super Micro Computer Inc    762.490723
# 6   BYAN IJ Equity         Bayan Resources Tbk PT  18000.000000
#
#    6Y Total Return%  6Y Annualised Return        EPS       FCFPS  \
# 0        300.470588              1.589450  13.526731    4.789175
# 1         72.222393              1.045380  10.867053         NaN
# 4         43.643866              0.883477  28.427895 -131.325263
# 5         30.004074              0.772433  19.230000  -33.824639
# 6         22.218526              0.689037   0.034590    0.017968
#
#       FCF Yield  EPS Growth  5 YR EPS Growth  5 YR Forecast EPS Growth  \
# 0  1.168091e-02   88.549203       336.721739                336.721739
# 1           NaN   69.538759        92.741867                 92.741867
# 4 -3.602641e-02   30.473393        52.594889                 52.594889
# 5 -4.436072e-02   72.776280        80.841010                 80.841010
# 6  9.982250e-07  -46.202778        63.130366                 63.130366
#
#      Multiple  Earnings Yield  EPS 5 Years Forecast  \
# 0   43.264225        0.023114          21489.034753
# 1   30.251914        0.033056            289.062723
# 4  137.441817        0.007276            235.203967
# 5   42.665360        0.023438            371.932307
# 6   32.120832        0.031132              0.399599
#
#    5Y Forecast Earnings Yield  1Y Expected TR (No Change in Multiple)  \
# 0                   52.412280                                3.468160
# 1                    0.879278                                0.991131
# 4                    0.064523                                0.537051
# 5                    0.487786                                0.850796
# 6                    0.000022                                0.682090
#
#    5Y Expected Annualised TR (No Change in Multiple)  5Y Multiple  \
# 0                                           4.891563         50.0
# 1                                           1.212056         50.0
# 4                                           0.662944         50.0
# 5                                           1.045355         50.0
# 6                                           0.810109         50.0
#
#    5Y Expected Annualised TR (Change in Multiple)
# 0                                        0.385382
# 1                                        0.560851
# 4                                       -0.057591
# 5                                        0.391834
# 6                                        0.529972

# %%
asset_df.to_excel(os.path.join(current_dir,"../../data/Top_Stocks.xlsx"))

# %% [markdown]
# ## Re-do with more complicated bloomberg data

# %% [markdown]
# ### Import the data

# %% [markdown]
# #### Snapshot Data

# %%
df = pd.read_sql("SELECT * FROM 'table_2'", sqlq.engine)

# %% [markdown]
# #### Historic Data

# %%
#df_2 = pd.read_excel(os.path.join(current_dir, "../../data/bloomberg_data.xlsx"))

# %% [markdown]
# ### Rename Some of the columns

# %%
df.rename(columns = {'Unnamed: 0': 'security_key'}, inplace = True)

# %% [markdown]
# ### Take a deeper look at some of the columns, especially annualised performance over the last 5 years

# %%
pd.set_option('display.max_columns', None)
df.sort_values(by = "current_ann_trr_5yr", ascending = False)
# Out:
#        security_key                  security_name  px_last  current_trr_ytd  \
# 182   IHC UH Equity  International Holding Co PJSC  414.500         3.754693
# 240  NVDA US Equity                    NVIDIA Corp  125.830       154.121900
# 309  TSLA US Equity                      Tesla Inc  251.520         1.223442
# 203   LLY US Equity                 Eli Lilly & Co  914.570        57.423540
# 199  KLAC US Equity                       KLA Corp  855.210        47.740160
# ..              ...                            ...      ...              ...
# 245  P911 GR Equity         Dr Ing hc F Porsche AG   71.320        -7.935353
# 255  PLTR US Equity      Palantir Technologies Inc   27.230        58.590560
# 258   PRX NA Equity                      Prosus NV   32.835        21.678700
# 272  ROSN RM Equity            Rosneft Oil Co PJSC  556.150              NaN
# 280  SBER RM Equity        Sberbank of Russia PJSC  313.500              NaN
#
#       cur_mkt_cap  current_trr_ytd_1  current_ann_trr_3yr  \
# 182  9.092223e+11           3.754693            48.553680
# 240  3.095418e+12         154.121900            84.915230
# 309  8.021466e+11           1.223442             4.942127
# 203  8.692123e+11          57.423540            58.498100
# 199  1.151454e+11          47.740160            42.903900
# ..            ...                ...                  ...
# 245  6.497252e+10          -7.935353                  NaN
# 255  6.063839e+10          58.590560             5.661175
# 258  8.467185e+10          21.678700            -2.140393
# 272  5.894177e+12                NaN                  NaN
# 280  6.767508e+12                NaN                  NaN
#
#      current_ann_trr_5yr  month_end_trr_10yr  minimum_total_return  \
# 182            209.09870           79.483020                   NaN
# 240            100.09750           75.716730                   NaN
# 309             74.82077           28.611223                   NaN
# 203             54.49960           33.149180                   NaN
# 199             50.77105           33.369447                   NaN
# ..                   ...                 ...                   ...
# 245                  NaN                 NaN                   NaN
# 255                  NaN                 NaN                   NaN
# 258                  NaN                 NaN                   NaN
# 272                  NaN           14.568560                   NaN
# 280                  NaN           19.087700                   NaN
#
#      hist_trr_prev_1yr  current_trr_mtd  eps_growth  \
# 182          -2.560967         1.593137   84.368610
# 240         239.019100         1.853651  584.659091
# 309         101.721000        27.107340   17.661692
# 203          60.905030         1.015044  -16.017316
# 199          56.029640         3.723425   10.013593
# ..                 ...              ...         ...
# 245         -14.915430         2.589187    4.044118
# 255         167.445400         7.500986         NaN
# 258          -8.503771        -1.277809   62.145326
# 272          79.459110              NaN         NaN
# 280         114.086700              NaN  246.924885
#
#      geo_grow_diluted_eps_cont_ops  diluted_eps_cont_ops_5yr_avg_gr  \
# 182                     196.464049                       280.792101
# 240                      51.441971                       168.466403
# 309                            NaN                              NaN
# 203                      13.459286                        22.494442
# 199                      25.827603                        25.775781
# ..                             ...                              ...
# 245                            NaN                              NaN
# 255                            NaN                              NaN
# 258                      10.844301                        75.982422
# 272                            NaN                              NaN
# 280                      12.248339                              NaN
#
#      5y_geo_growth_diluted_eps   earn_yld    pe_ratio  \
# 182                 215.717287   3.263385   30.643028
# 240                  48.401189   1.364966   73.261887
# 309                        NaN   0.883704  113.160080
# 203                  13.129725   1.133808   88.198379
# 199                  36.480119   2.637979   37.907804
# ..                         ...        ...         ...
# 245                        NaN   7.182267   13.923180
# 255                        NaN   0.461469  216.699291
# 258                  20.394921   7.447539   13.427254
# 272                        NaN        NaN         NaN
# 280                  12.596420  22.606001    4.423604
#
#      five_yr_avg_price_earnings  long_term_price_earnings_ratio  \
# 182                   34.160428                             NaN
# 240                   61.097322                      366.074157
# 309                         NaN                      405.377228
# 203                   38.449955                      135.566601
# 199                   17.870855                       62.973129
# ..                          ...                             ...
# 245                         NaN                             NaN
# 255                         NaN                             NaN
# 258                   18.448145                             NaN
# 272                         NaN                        8.225822
# 280                    6.049010                        6.381916
#
#      best_pe_ratio  pr_eps_growth_plus_yld
# 182            NaN                     NaN
# 240      43.136784               42.817484
# 309      94.449869                     NaN
# 203      62.526150               40.544444
# 199      31.722616                9.645935
# ..             ...                     ...
# 245      12.298672                6.568923
# 255      79.619883                     NaN
# 258      11.597772               46.123187
# 272            NaN                     NaN
# 280            NaN                     NaN
#
# [344 rows x 22 columns]

# %% [markdown]
# ### Fill in blanks for 5 year geometric average earnings growth to get return calc

# %%
def clean_and_fill(df):
    """
    Remove rows with NaN values across all specified columns, and fill NaNs in the 
    '5y_geo_growth_diluted_eps' column with the first available non-null value from other columns.

    Parameters:
    - df (DataFrame): The DataFrame to process.

    Returns:
    - DataFrame: The processed DataFrame.
    """
    # Define the columns to check for NaN values
    columns_to_check = [
        'eps_growth', 
        'geo_grow_diluted_eps_cont_ops', 
        'diluted_eps_cont_ops_5yr_avg_gr', 
        '5y_geo_growth_diluted_eps'
    ]
    
    # Drop rows where all specified columns are NaN and create a copy
    df_cleaned = df.dropna(subset=columns_to_check, how='all').copy()
    
    # Fill NaNs in '5y_geo_growth_diluted_eps' with the first available non-null value
    df_cleaned['5y_geo_growth_diluted_eps'] = df_cleaned['5y_geo_growth_diluted_eps'].fillna(
        df_cleaned['diluted_eps_cont_ops_5yr_avg_gr']
    ).fillna(
        df_cleaned['geo_grow_diluted_eps_cont_ops']
    ).fillna(
        df_cleaned['eps_growth']
    )
    
    # Merge the cleaned '5y_geo_growth_diluted_eps' back into the original df
    df_merged = df.merge(
        df_cleaned[['5y_geo_growth_diluted_eps']], 
        left_index=True, 
        right_index=True, 
        how='left', 
        suffixes=('', '_filled')
    )
    
    # Use the filled values to update the original column
    df_merged['5y_geo_growth_diluted_eps'] = df_merged['5y_geo_growth_diluted_eps_filled']

    # Drop the extra column after merging
    df_merged.drop(columns=['5y_geo_growth_diluted_eps_filled'], inplace=True)

    return df_merged

df = clean_and_fill(df)

# %%
pd.set_option('display.max_rows', 10)
df
# Out:
#          security_key                  security_name    px_last  \
# 0    000333 CH Equity             Midea Group Co Ltd      64.00
# 1    000660 KS Equity                   SK Hynix Inc  236000.00
# 2    000858 CH Equity         Wuliangye Yibin Co Ltd     128.95
# 3    005930 KS Equity     Samsung Electronics Co Ltd   87100.00
# 4      1088 HK Equity    China Shenhua Energy Co Ltd      37.35
# ..                ...                            ...        ...
# 339     WMT US Equity                    Walmart Inc      70.04
# 340     XLK US Equity  Technology Select Sector SPDR     232.88
# 341     XOM US Equity               Exxon Mobil Corp     113.37
# 342     ZTS US Equity                     Zoetis Inc     174.96
# 343    ZURN SW Equity      Zurich Insurance Group AG     471.00
#
#      current_trr_ytd   cur_mkt_cap  current_trr_ytd_1  current_ann_trr_3yr  \
# 0          22.189810  4.467274e+11          22.189810             1.145894
# 1          67.065220  1.718086e+14          67.065220            26.322820
# 2          -8.096358  5.005334e+11          -8.096358           -20.547550
# 3          11.451140  5.199681e+14          11.451140             4.956467
# 4          49.269520  9.256450e+11          49.269520            50.082570
# ..               ...           ...                ...                  ...
# 339        34.194950  5.633698e+11          34.194950            16.329720
# 340        21.406060  7.253185e+10          21.406060            16.810780
# 341        15.379720  5.085696e+11          15.379720            28.476220
# 342       -10.902600  7.983340e+10         -10.902600            -3.100194
# 343        13.312770  6.893356e+10          13.312770            15.286000
#
#      current_ann_trr_5yr  month_end_trr_10yr  minimum_total_return  \
# 0               6.886530           21.267630                   NaN
# 1              29.949640           18.934220                   NaN
# 2               1.532926           24.229110                   NaN
# 3              17.323510           14.683610                   NaN
# 4              31.524360           15.390870                   NaN
# ..                   ...                 ...                   ...
# 339            15.058430           12.721773                   NaN
# 340            25.201440           20.971694              -6.27495
# 341            13.750990            5.789788                   NaN
# 342             9.685760           19.094823                   NaN
# 343            12.268050           12.320800                   NaN
#
#      hist_trr_prev_1yr  current_trr_mtd  eps_growth  \
# 0            10.856210        -0.775194   11.248249
# 1            90.694470        -0.211417         NaN
# 2           -20.579780         0.710718   13.190809
# 3            44.898240         6.871166  -73.550949
# 4            32.600360         3.894291  -11.362398
# ..                 ...              ...         ...
# 339          12.885850         3.441149   34.265734
# 340          56.016360         2.939491         NaN
# 341          -6.243449        -1.520153  -32.956259
# 342          35.899130         0.922938   12.638581
# 343           4.901004        -1.690671   -3.386005
#
#      geo_grow_diluted_eps_cont_ops  diluted_eps_cont_ops_5yr_avg_gr  \
# 0                         9.349578                         9.054256
# 1                              NaN                              NaN
# 2                        17.636014                         5.300772
# 3                       -19.810062                        78.530824
# 4                         7.717313                        10.502693
# ..                             ...                              ...
# 339                       6.222695                        12.018819
# 340                            NaN                              NaN
# 341                      14.081479                              NaN
# 342                      11.126667                        10.580528
# 343                       8.770028                         9.910130
#
#      5y_geo_growth_diluted_eps  earn_yld   pe_ratio  \
# 0                     9.621721  7.780530  12.852595
# 1                          NaN -2.836933        NaN
# 2                    17.506920  6.335673  15.783643
# 3                   -19.895532  3.329506  30.034482
# 4                     7.950673  8.938004  11.188180
# ..                         ...       ...        ...
# 339                  20.450675  3.332766  30.005111
# 340                        NaN       NaN        NaN
# 341                  12.744766  7.714310  12.962921
# 342                  11.590717  3.021147  33.100011
# 343                   3.667742  5.690896  17.571924
#
#      five_yr_avg_price_earnings  long_term_price_earnings_ratio  \
# 0                     16.435892                       18.269357
# 1                           NaN                       29.344968
# 2                     33.542675                       28.014891
# 3                     19.193506                       17.522041
# 4                      6.399881                       14.706056
# ..                          ...                             ...
# 339                   23.495331                       33.485832
# 340                         NaN                             NaN
# 341                         NaN                       18.606106
# 342                   39.442777                       44.330586
# 343                   15.295567                       19.603038
#
#      best_pe_ratio  pr_eps_growth_plus_yld
# 0              NaN                     NaN
# 1         7.878897               42.571356
# 2              NaN               13.642920
# 3        13.515566               63.123398
# 4              NaN                     NaN
# ..             ...                     ...
# 339      28.310428                9.365228
# 340            NaN                     NaN
# 341      11.945001                9.316867
# 342      29.836289               11.282233
# 343      12.625905               21.440170
#
# [344 rows x 22 columns]

# %% [markdown]
# ### Use the multiple predictor forecast total returns and later rank by forecast total returns

# %%
def gen_returns(df, decr = 0.7, factor = 0.5):
    df["exp_geo_growth_diluted_eps"] = decr*df["5y_geo_growth_diluted_eps"]
    df["exp_pe_ratio"] = df["exp_geo_growth_diluted_eps"].apply(lambda x: predict_multiple(x, 5))
    df["exp_pe_ratio_lb"] = [max([elem, 8]) for elem in factor*df["pe_ratio"]]
    df["exp_ann_trr"] = [predict_roi(df["exp_geo_growth_diluted_eps"][i], df["pe_ratio"][i], df["exp_pe_ratio"][i]) for i in df.index]
    df["exp_ann_trr"] = df["exp_ann_trr"].fillna(decr*df["current_ann_trr_5yr"]/100)
    df["exp_ann_trr_lb"] = [predict_roi(df["exp_geo_growth_diluted_eps"][i], df["pe_ratio"][i], df["exp_pe_ratio_lb"][i]) for i in df.index]
    df["exp_ann_trr_lb"] = df["exp_ann_trr_lb"].fillna(decr*factor*df["current_ann_trr_5yr"]/100)
    return df
df = gen_returns(df)
df.to_excel(os.path.join(data_dir, "unfiltered_basket.xlsx"))

# %% [markdown]
# ### Define a function to apply some exclusion criteria
# * Get rid of any stocks that were in the bottom 30% of performers in the 1yr, 3yr and 5yr annualised TR
# * Get rid of any stocks with EPS growth in the last year, geometrically over 5 years or average over 5 years in the bottom 20 % of performers

# %%
def exclude(df, tr_floor=0, eps_g_floor=0.0, tr_pctl_floor=5, eps_g_pctl_floor=5, five_yr_ann_eps_g_min=0, exp_trr_lb_floor = 0.06):
    """
    Filter DataFrame rows based on conditions applied to columns containing 'trr' or growth-related terms.

    Parameters:
    - df (DataFrame): The DataFrame to filter.
    - tr_floor (float): Minimum threshold for 'trr' columns.
    - eps_g_floor (float): Minimum threshold for EPS growth columns.
    - tr_pctl_floor (float): Percentile threshold for 'trr' columns.
    - eps_g_pctl_floor (float): Percentile threshold for EPS growth columns.
    - five_yr_ann_eps_g_min (float): Not used in this version, reserved for future conditions.

    Returns:
    - DataFrame: The filtered DataFrame.
    """
    
    # Filter columns matching the regex for 'trr'
    trr_cols = df.filter(regex='trr')
    for col in trr_cols.columns:
        # Compute the given percentile for each 'trr' column
        percentile = np.nanpercentile(df[col], tr_pctl_floor)
        
        # Create a mask to filter rows where each 'trr' column is either NaN or meets conditions
        mask = (df[col].isna()) | ((df[col] >= percentile) & (df[col] >= tr_floor))
        
        # Apply the mask to filter the DataFrame for each 'trr' column
        df = df[mask]

    # Filter columns matching the regex for 'eps' or 'earnings' combined with 'gr'
    eps_growth_cols = df.filter(regex='(gr.*eps|eps.*gr|gr.*earnings|earnings.*gr)')
    for col in eps_growth_cols.columns:
        # Compute the given percentile for each growth-related column
        percentile = np.nanpercentile(df[col], eps_g_pctl_floor)

        # Create a mask to filter rows where each column is either NaN or meets conditions
        mask = (df[col].isna()) | ((df[col] >= percentile) & (df[col] >= eps_g_floor))

        # Apply the mask to filter the DataFrame for each column
        df = df[mask]

    # Eliminate stocks that have a chance of performing below a threshold
    mask = (df["exp_ann_trr_lb"].isna()) | (df["exp_ann_trr_lb"] <= exp_trr_lb_floor)
     # Rank by total returns and select up to top 50
    df = df.sort_values(by = "exp_ann_trr", ascending = False)
    
    
    return df.head(50)

# Example usage
filtered_df = exclude(df)
filtered_df
# Out:
#           security_key                   security_name   px_last  \
# 281     SBIN IN Equity             State Bank of India    859.75
# 129       CS FP Equity                          AXA SA     31.96
# 280     SBER RM Equity         Sberbank of Russia PJSC    313.50
# 179  ICICIBC IN Equity                  ICICI Bank Ltd   1233.40
# 60      ABNB US Equity                      Airbnb Inc    152.50
# ..                 ...                             ...       ...
# 322      VEA US Equity  Vanguard FTSE Developed Market     50.48
# 105     BREN IJ Equity  Barito Renewables Energy Tbk P  10300.00
# 115      CEG US Equity       Constellation Energy Corp    211.29
# 255     PLTR US Equity       Palantir Technologies Inc     27.23
# 272     ROSN RM Equity             Rosneft Oil Co PJSC    556.15
#
#      current_trr_ytd   cur_mkt_cap  current_trr_ytd_1  current_ann_trr_3yr  \
# 281         36.14766  7.672935e+12           36.14766            28.683860
# 129         14.99040  7.259724e+10           14.99040            21.742890
# 280              NaN  6.767508e+12                NaN                  NaN
# 179         23.76079  8.678435e+12           23.76079            25.004470
# 60          12.01704  9.821668e+10           12.01704             2.277222
# ..               ...           ...                ...                  ...
# 322          6.99156  1.356206e+11            6.99156             2.931059
# 105         37.83897  1.377998e+15           37.83897                  NaN
# 115         81.40372  6.658190e+10           81.40372                  NaN
# 255         58.59056  6.063839e+10           58.59056             5.661175
# 272              NaN  5.894177e+12                NaN                  NaN
#
#      current_ann_trr_5yr  month_end_trr_10yr  minimum_total_return  \
# 281            20.758480            13.45286                   NaN
# 129            12.263980            11.53627                   NaN
# 280                  NaN            19.08770                   NaN
# 179            24.150440            17.69244                   NaN
# 60                   NaN                 NaN                   NaN
# ..                   ...                 ...                   ...
# 322             7.041403             4.54140               -3.2307
# 105                  NaN                 NaN                   NaN
# 115                  NaN                 NaN                   NaN
# 255                  NaN                 NaN                   NaN
# 272                  NaN            14.56856                   NaN
#
#      hist_trr_prev_1yr  current_trr_mtd  eps_growth  \
# 281           6.658328         1.272158   20.561347
# 129          20.141520         4.546939   47.417840
# 280         114.086700              NaN  246.924885
# 179          12.790760         2.817610   29.328694
# 60           59.228070         0.573762  153.198653
# ..                 ...              ...         ...
# 322          17.937110         2.144883         NaN
# 105                NaN         2.233251         NaN
# 115          37.233570         5.502566         NaN
# 255         167.445400         7.500986         NaN
# 272          79.459110              NaN         NaN
#
#      geo_grow_diluted_eps_cont_ops  diluted_eps_cont_ops_5yr_avg_gr  \
# 281                      95.958450                       121.817039
# 129                       8.239508                       320.191972
# 280                      12.248339                              NaN
# 179                      62.597397                       106.664939
# 60                             NaN                              NaN
# ..                             ...                              ...
# 322                            NaN                              NaN
# 105                            NaN                              NaN
# 115                            NaN                              NaN
# 255                            NaN                              NaN
# 272                            NaN                              NaN
#
#      5y_geo_growth_diluted_eps   earn_yld    pe_ratio  \
# 281                  96.284031   8.743239   11.437409
# 129                  31.699295   9.843004   10.159500
# 280                  12.596420  22.606001    4.423604
# 179                  56.833793   5.123236   19.518912
# 60                  153.198653   4.891241   20.444708
# ..                         ...        ...         ...
# 322                        NaN        NaN         NaN
# 105                        NaN        NaN         NaN
# 115                        NaN   3.288681   30.407327
# 255                        NaN   0.461469  216.699291
# 272                        NaN        NaN         NaN
#
#      five_yr_avg_price_earnings  long_term_price_earnings_ratio  \
# 281                   10.850982                       29.051121
# 129                   12.056767                       13.387884
# 280                    6.049010                        6.381916
# 179                   19.727694                       35.477266
# 60                          NaN                             NaN
# ..                          ...                             ...
# 322                         NaN                             NaN
# 105                         NaN                             NaN
# 115                         NaN                             NaN
# 255                         NaN                             NaN
# 272                         NaN                        8.225822
#
#      best_pe_ratio  pr_eps_growth_plus_yld  exp_geo_growth_diluted_eps  \
# 281            NaN                     NaN                   67.398822
# 129       9.255720               14.595244                   22.189506
# 280            NaN                     NaN                    8.817494
# 179            NaN                     NaN                   39.783655
# 60       31.314168                     NaN                  107.239057
# ..             ...                     ...                         ...
# 322            NaN                     NaN                         NaN
# 105            NaN                     NaN                         NaN
# 115      27.440260               15.190596                         NaN
# 255      79.619883                     NaN                         NaN
# 272            NaN                     NaN                         NaN
#
#      exp_pe_ratio  exp_pe_ratio_lb  exp_ann_trr  exp_ann_trr_lb
# 281     50.000000         8.000000     1.158589        0.257865
# 129     37.279381         8.000000     0.925689        0.234932
# 280     20.611128         8.000000     0.895344        0.463606
# 179     50.000000         9.759456     0.806317        0.109082
# 60      50.000000        10.222354     0.778630        0.105812
# ..            ...              ...          ...             ...
# 322           NaN              NaN     0.049290        0.024645
# 105           NaN              NaN          NaN             NaN
# 115           NaN        15.203663          NaN             NaN
# 255           NaN       108.349646          NaN             NaN
# 272           NaN              NaN          NaN             NaN
#
# [46 rows x 27 columns]
